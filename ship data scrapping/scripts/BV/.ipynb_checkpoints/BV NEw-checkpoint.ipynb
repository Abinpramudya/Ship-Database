# %%
import os
import time
import csv
import re
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.action_chains import ActionChains

# %%
# Get the current working directory
current_dir = os.getcwd()

# Move up a couple of folders
project_dir = os.path.abspath(os.path.join(current_dir, "../../"))

# %%
# Define the path to your YAML file
yaml_file = os.path.abspath(os.path.join(current_dir, "../../config.yaml"))

# Read the YAML file
with open(yaml_file, 'r') as file:
    config = yaml.safe_load(file)

# Access the values from the YAML file
vessel_type = config['vessel_type']
class_type = config['class']
base = config['base']

# %%
#edit sesuai kebutuhan
num = base + 1
filenum = str(num)

# %%
#directory file csv
read_path = 'C:/Users/abinp/Documents/ITS/side projects/new/ship data scrapping/input/{}/split_{}.csv'.format(vessel_type,filenum)
write_path = 'C:/Users/abinp/Documents/ITS/side projects/new/ship data scrapping/output/{}/{}/{}.csv'.format(kelas,vessel_type,filenum)

# %%
# Check if input file exists
if os.path.exists(read_path):
    print(f"CSV read file is found, continuing...")
else:
    print(f"CSV read file is not found")
    print('exiting....')
    
# Check if output file exists and create it if necessary
if os.path.exists(write_path):
    print(f"CSV write file  is found, continuing...")
else:
    print(f"CSV write file is not found, creating one...")
    os.makedirs(os.path.dirname(write_path), exist_ok=True) # Create output directory if it doesn't exist
    with open(write_path, 'w', newline='') as f:
        writer = csv.writer(f)
# Out:
# CSV read file is found, continuing...
# CSV write file  is found, continuing...

# %%
def search(IMO):
    driver.get("https://marine-offshore.bureauveritas.com/bv-fleet/#/bv-fleet/")

    try:
        #cookie button
        cookie_button = WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.XPATH, '/html/body/div[1]/div/div/div[2]/div[3]/div[1]/button[1]')))
        actions = ActionChains(driver)
        actions.move_to_element(cookie_button)
        actions.click().perform()
    except:
        pass

    #search bar
    search_field = WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.XPATH, '/html/body/div[2]/div/main/div/div/div[2]/div/app-root/div/app-ship-basic-search/div/div/form/fieldset/div[1]/div/div/div[1]/input')))
    search_field.send_keys(IMO)

    # search button
    search_button = WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.XPATH, '/html/body/div[2]/div/main/div/div/div[2]/div/app-root/div/app-ship-basic-search/div/div/form/fieldset/div[2]/div[1]/div/button')))
    actions = ActionChains(driver)
    actions.move_to_element(search_button)
    actions.click().perform()

    #ships button
    ship_button = WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.XPATH, '/html/body/div[2]/div/main/div/div/div[2]/div/app-root/div/app-ship-basic-search/div/div/div[2]/ul/li/div/div[1]/a[1]')))
    actions = ActionChains(driver)
    actions.move_to_element(ship_button)
    actions.click().perform()

# %%
def shipdata():
    global LOA , LPP , B , H , T
    global DWT , NT , GT , LT
    global NAME , REGISTER , IMO , vessel_type
    global link
    
    time.sleep(3)
    
    NAME = driver.find_element(By.XPATH,'/html/body/app-popup/div/div[2]/div[2]/app-ship-details/div/div/table[1]/tbody/tr[6]/td[2]')
    REGISTER = driver.find_element(By.XPATH,'/html/body/app-popup/div/div[2]/div[2]/app-ship-details/div/div/table[1]/tbody/tr[2]/td[2]')
    IMO = driver.find_element(By.XPATH,'/html/body/app-popup/div/div[2]/div[2]/app-ship-details/div/div/table[1]/tbody/tr[4]/td[2]')
    vessel_type = driver.find_element(By.XPATH,'/html/body/app-popup/div/div[2]/div[2]/app-ship-details/div/div/table[1]/tbody/tr[10]/td[2]')
    
    #principal dimension
    LOA = driver.find_element(By.XPATH,'/html/body/app-popup/div/div[2]/div[2]/app-ship-details/div/div/table[3]/tbody/tr[8]/td[2]')
    LPP = driver.find_element(By.XPATH,'/html/body/app-popup/div/div[2]/div[2]/app-ship-details/div/div/table[3]/tbody/tr[10]/td[2]')
    B = driver.find_element(By.XPATH,'/html/body/app-popup/div/div[2]/div[2]/app-ship-details/div/div/table[3]/tbody/tr[12]/td[2]')
    H = driver.find_element(By.XPATH,'/html/body/app-popup/div/div[2]/div[2]/app-ship-details/div/div/table[3]/tbody/tr[14]/td[2]')
    T = driver.find_element(By.XPATH,'/html/body/app-popup/div/div[2]/div[2]/app-ship-details/div/div/table[3]/tbody/tr[16]/td[2]')
    
    #ship tonnage
    GT = driver.find_element(By.XPATH,'/html/body/app-popup/div/div[2]/div[2]/app-ship-details/div/div/table[3]/tbody/tr[2]/td[2]')
    NT = driver.find_element(By.XPATH,'/html/body/app-popup/div/div[2]/div[2]/app-ship-details/div/div/table[3]/tbody/tr[4]/td[2]')
    DWT = driver.find_element(By.XPATH,'/html/body/app-popup/div/div[2]/div[2]/app-ship-details/div/div/table[3]/tbody/tr[6]/td[2]')
    
    link = 'https://www.vesselfinder.com/vessels/details/{}'.format(IMO.text)
    
    
    # Print all the variables
    print("NAME:", NAME.text)
    print("REGISTER:", REGISTER.text)
    print("IMO:", IMO.text)
    print("vessel_type:", vessel_type.text)
    print("LOA:", LOA.text)
    print("LPP:", LPP.text)
    print("B:", B.text)
    print("H:", H.text)
    print("T:", T.text)
    print("GT:", GT.text)
    print("NT:", NT.text)
    print("DWT:", DWT.text)
    print("link:", link)

# %%
# Set up the webdriver
driver = webdriver.Chrome()


IMO = '9116694'

search(IMO)
shipdata()
# Out:
# NAME: AQUARIUS 88
# REGISTER: 38101R
# IMO: 9116694
# vessel_type: 3FBV5
# LOA: 189.99 m
# LPP: 180 m
# B: 32.2 m
# H: 16.5 m
# T: 11.71 m
# GT: 27763
# NT: 16337
# DWT: 49061 ton
# link: https://www.vesselfinder.com/vessels/details/9116694

# %%
# Define the fieldnames for the CSV file
fieldnames = ['NAME', 'REGISTER', 'IMO', 'TYPE', 'LOA', 'LPP', 'B', 'H', 'T',  'GT', 'NT', 'DWT', 'Link']

# %%
# Set up the webdriver
driver = webdriver.Chrome()

# Open the CSV file for writing
with open(write_path, mode='w', newline='') as details_file:
    writer = csv.DictWriter(details_file, fieldnames=fieldnames)
    writer.writeheader()
    
    # Open the input file and loop through each vessel name
    with open(read_path, newline='') as csvfile:
        reader = csv.reader(csvfile)        
        for row in reader:
            IMO = row[0]
            try:
                search(IMO)
                shipdata()
            except:
                continue
                
                           
            details_dict = {'NAME': NAME.text, 'REGISTER': REGISTER.text, 'IMO': IMO.text, 'TYPE':  vessel_type.text, 'LOA': LOA.text, 'LPP': LPP.text, 'B': B.text, 'H': H.text, 'T': T.text, 'GT': GT.text, 'NT': NT.text, 'DWT': DWT.text, 'Link': link}
            writer.writerow(details_dict)
            print('ketemu IMO :',IMO.text)
# Out:
# NAME: TAC IMOLA
# REGISTER: 31241K
# IMO: 9932103
# vessel_type: Bulk carrier
# LOA: 179.9 m
# LPP: 176.85 m
# B: 30 m
# H: 15.1 m
# T: 10.8 m
# GT: 25163
# NT: 13493
# DWT: 40256 ton
# link: https://www.vesselfinder.com/vessels/details/9932103
# ketemu IMO : 9932103
# NAME: ASIA SPIRIT
# REGISTER: 19298D
# IMO: 9637430
# vessel_type: Bulk carrier
# LOA: 179.9 m
# LPP: 171.5 m
# B: 28.4 m
# H: 15 m
# T: 10.8 m
# GT: 22402
# NT: 12019
# DWT: 35031 ton
# link: https://www.vesselfinder.com/vessels/details/9637430
# ketemu IMO : 9637430
# NAME: BELLE PLAINE
# REGISTER: 22963M
# IMO: 9638434
# vessel_type: Bulk carrier
# LOA: 179.9 m
# LPP: 175 m
# B: 30 m
# H: 14.6 m
# T: 10 m
# GT: 23405
# NT: 11922
# DWT: 36000 ton
# link: https://www.vesselfinder.com/vessels/details/9638434
# ketemu IMO : 9638434
# NAME: MAR
# REGISTER: 16318P
# IMO: 9586447
# vessel_type: Bulk carrier
# LOA: 119.95 m
# LPP: 111.97 m
# B: 16.8 m
# H: 8.2 m
# T: 6.68 m
# GT: 5235
# NT: 2913
# DWT: 6708 ton
# link: https://www.vesselfinder.com/vessels/details/9586447
# ketemu IMO : 9586447
# NAME: DEWI AMBARWATI
# REGISTER: 14311H
# IMO: 9528861
# vessel_type: YCNB2
# LOA: 183.4 m
# LPP: 175.2 m
# B: 26 m
# H: 14 m
# T: 10.02 m
# GT: 19724
# NT: 10849
# DWT: 32000 ton
# link: https://www.vesselfinder.com/vessels/details/9528861
# ketemu IMO : 9528861
# NAME: KOTOR
# REGISTER: 19474U
# IMO: 9575981
# vessel_type: Bulk carrier
# LOA: 179.9 m
# LPP: 171.5 m
# B: 28.4 m
# H: 15 m
# T: 10.8 m
# GT: 22456
# NT: 12060
# DWT: 35000 ton
# link: https://www.vesselfinder.com/vessels/details/9575981
# ketemu IMO : 9575981
# NAME: PEARL IVY
# REGISTER: 41027W
# IMO: 9580015
# vessel_type: General cargo ship
# LOA: 175.53 m
# LPP: 167 m
# B: 29.4 m
# H: 13.7 m
# T: 9.64 m
# GT: 19812
# NT: 10395
# DWT: 31848 ton
# link: https://www.vesselfinder.com/vessels/details/9580015
# ketemu IMO : 9580015
# NAME: MATRIX
# REGISTER: 10158T
# IMO: 9454125
# vessel_type: 3E3563
# LOA: 112.8 m
# LPP: 106.17 m
# B: 17.2 m
# H: 9.1 m
# T: 6.9 m
# GT: 5087
# NT: 2625
# DWT: 7300 ton
# link: https://www.vesselfinder.com/vessels/details/9454125
# ketemu IMO : 9454125
# NAME: AMAR GLYFADA
# REGISTER: 19404T
# IMO: 9250567
# vessel_type: V3WW8
# LOA: 176.82 m
# LPP: 168.56 m
# B: 29.4 m
# H: 13.5 m
# T: 9.56 m
# GT: 19795
# NT: 11034
# DWT: 31838 ton
# link: https://www.vesselfinder.com/vessels/details/9250567
# ketemu IMO : 9250567
# NAME: TURKAN SAYLAN
# REGISTER: 02634Q
# IMO: 9250945
# vessel_type: 5LET7
# LOA: 137.9 m
# LPP: 131 m
# B: 25 m
# H: 11.5 m
# T: 8.42 m
# GT: 11403
# NT: 6277
# DWT: 18721 ton
# link: https://www.vesselfinder.com/vessels/details/9250945
# ketemu IMO : 9250945
# NAME: AFRICAN CORMORANT
# REGISTER: 17877J
# IMO: 9618006
# vessel_type: C6GC3
# LOA: 179.99 m
# LPP: 176.65 m
# B: 30 m
# H: 15 m
# T: 10.5 m
# GT: 24725
# NT: 13677
# DWT: 40481 ton
# link: https://www.vesselfinder.com/vessels/details/9618006
# ketemu IMO : 9618006
# NAME: WESTERN FEDORA
# REGISTER: 19662Y
# IMO: 9609689
# vessel_type: Bulk carrier
# LOA: 187 m
# LPP: 178 m
# B: 28.6 m
# H: 15.6 m
# T: 10.4 m
# GT: 22668
# NT: 11856
# DWT: 37000 ton
# link: https://www.vesselfinder.com/vessels/details/9609689
# ketemu IMO : 9609689
# NAME: HALISDEMIR
# REGISTER: 11346K
# IMO: 9517331
# vessel_type: 3EIS3
# LOA: 119.95 m
# LPP: 111.97 m
# B: 16.8 m
# H: 8.2 m
# T: 6.28 m
# GT: 5164
# NT: 2913
# DWT: 7000 ton
# link: https://www.vesselfinder.com/vessels/details/9517331
# ketemu IMO : 9517331
# NAME: ST. PETER
# REGISTER: 12376E
# IMO: 9437529
# vessel_type: Bulk carrier
# LOA: 179.9 m
# LPP: 171.5 m
# B: 28.4 m
# H: 14.1 m
# T: 10.15 m
# GT: 20748
# NT: 11689
# DWT: 32688 ton
# link: https://www.vesselfinder.com/vessels/details/9437529
# ketemu IMO : 9437529
# NAME: CORNELIA
# REGISTER: 31695D
# IMO: 9216597
# vessel_type: General cargo ship
# LOA: 175 m
# LPP: 163.64 m
# B: 23.1 m
# H: 13.65 m
# T: 8.5 m
# GT: 16807
# NT: 7860
# DWT: 24765 ton
# link: https://www.vesselfinder.com/vessels/details/9216597
# ketemu IMO : 9216597
# NAME: IOANNIS S
# REGISTER: 36194T
# IMO: 9624330
# vessel_type: D5RZ5
# LOA: 169.37 m
# LPP: 160.4 m
# B: 27.2 m
# H: 13.6 m
# T: 9.8 m
# GT: 17027
# NT: 10108
# DWT: 28401 ton
# link: https://www.vesselfinder.com/vessels/details/9624330
# ketemu IMO : 9624330
# NAME: BANGLAR JOYJATRA
# REGISTER: 35787B
# IMO: 9793820
# vessel_type: Bulk carrier
# LOA: 179.95 m
# LPP: 177 m
# B: 32 m
# H: 15 m
# T: 10.5 m
# GT: 25818
# NT: 13271
# DWT: 38894 ton
# link: https://www.vesselfinder.com/vessels/details/9793820
# ketemu IMO : 9793820
# NAME: LANNA NAREE
# REGISTER: 20440U
# IMO: 9496939
# vessel_type: Bulk carrier
# LOA: 181 m
# LPP: 172 m
# B: 30 m
# H: 14.6 m
# T: 9.8 m
# GT: 22641
# NT: 11230
# DWT: 33842 ton
# link: https://www.vesselfinder.com/vessels/details/9496939
# ketemu IMO : 9496939
# NAME: WESTERN MOSCOW
# REGISTER: 30585W
# IMO: 9855410
# vessel_type: Bulk carrier
# LOA: 179.9 m
# LPP: 176.85 m
# B: 30 m
# H: 15 m
# T: 10.6 m
# GT: 25189
# NT: 12869
# DWT: 39492 ton
# link: https://www.vesselfinder.com/vessels/details/9855410
# ketemu IMO : 9855410
# NAME: WL MUROM
# REGISTER: 29330H
# IMO: 9674385
# vessel_type: VRVA7
# LOA: 180 m
# LPP: 176.75 m
# B: 30 m
# H: 14.7 m
# T: 10.65 m
# GT: 24199
# NT: 12794
# DWT: 37500 ton
# link: https://www.vesselfinder.com/vessels/details/9674385
# ketemu IMO : 9674385
# NAME: SEASTAR VENTURE
# REGISTER: 19683W
# IMO: 9612155
# vessel_type: ZDRC6
# LOA: 177.4 m
# LPP: 168 m
# B: 28.2 m
# H: 14.2 m
# T: 10.2 m
# GT: 20218
# NT: 11367
# DWT: 32500 ton
# link: https://www.vesselfinder.com/vessels/details/9612155
# ketemu IMO : 9612155
# NAME: FORTUNE HERO
# REGISTER: 16095W
# IMO: 9631694
# vessel_type: Bulk carrier
# LOA: 179.88 m
# LPP: 171.2 m
# B: 28.8 m
# H: 28.8 m
# T: 10.27 m
# GT: 22400
# NT: 11773
# DWT: 35000 ton
# link: https://www.vesselfinder.com/vessels/details/9631694
# ketemu IMO : 9631694
# NAME: NAVIN HAWK
# REGISTER: 12469F
# IMO: 9522738
# vessel_type: 7987
# LOA: 112.8 m
# LPP: 106 m
# B: 17.2 m
# H: 9.1 m
# T: 6.9 m
# GT: 5087
# NT: 2625
# DWT: 7561 ton
# link: https://www.vesselfinder.com/vessels/details/9522738
# ketemu IMO : 9522738
