# %%
import os
import time
import csv
import re
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.ui import WebDriverWait

# %%
#edit sesuai kebutuhan
vessel_type = 'bulk carrier'
filenum = '1'
kelas = 'NK'

# %%
#directory file csv
read_path = 'C:/Users/abinp/Documents/ITS/side projects/new/ship data scrapping/input/{}/split_{}.csv'.format(vessel_type,filenum)
write_path = 'C:/Users/abinp/Documents/ITS/side projects/new/ship data scrapping/output/{}/{}/{}.csv'.format(kelas,vessel_type,filenum)

# %%
# Check if input file exists
if os.path.exists(read_path):
    print(f"CSV read file is found, continuing...")
else:
    print(f"CSV read file is not found")
    print('exiting....')
    
# Check if output file exists and create it if necessary
if os.path.exists(write_path):
    print(f"CSV write file  is found, continuing...")
else:
    print(f"CSV write file is not found, creating one...")
    os.makedirs(os.path.dirname(write_path), exist_ok=True) # Create output directory if it doesn't exist
    with open(write_path, 'w', newline='') as f:
        writer = csv.writer(f)
# Out:
# CSV read file is found, continuing...
# CSV write file  is found, continuing...

# %%
def search(IMO):
    driver.get("https://www.classnk.com/register/regships/regships.aspx")

    search_field = WebDriverWait(driver, 5).until(EC.visibility_of_element_located((By.XPATH, '/html/body/div[2]/div/div/div/div[3]/div/form/div[3]/table/tbody/tr[2]/td/input')))
    search_field.send_keys(IMO)

    search_button = driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div/div[3]/div/form/div[3]/p/a[1]')
    search_button.click()
    
    ship_button = WebDriverWait(driver, 5).until(EC.visibility_of_element_located((By.XPATH, '/html/body/div[2]/div/div/div/div[3]/div/div[1]/div[2]/h3/a')))
    ship_button.click()

# %%
def newtab():
    # Open a new tab with the desired URL
    driver.execute_script("window.open('https://www.classnk.com/register/regships/one.aspx', '_blank');")

    # Switch to the new tab
    time.sleep(3)
    driver.switch_to.window(driver.window_handles[-1])

# %%
def shipdata():
    global LOA, LPP, B, H, T
    global DWT, NT, GT, LT
    global NAME, REGISTER, IMO, vessel_type
    global link
    
    wait = WebDriverWait(driver, 10) # Maximum wait time of 10 seconds
    
    NAME = wait.until(EC.visibility_of_element_located((By.XPATH,'/html/body/div/div/div[1]/div[3]/table/tbody/tr[8]/td')))
    REGISTER = wait.until(EC.visibility_of_element_located((By.XPATH,'/html/body/div/div/div[1]/div[3]/table/tbody/tr[2]/td')))
    IMO = wait.until(EC.visibility_of_element_located((By.XPATH,'/html/body/div/div/div[1]/div[3]/table/tbody/tr[3]/td')))
    vessel_type = wait.until(EC.visibility_of_element_located((By.XPATH,'/html/body/div/div/div[1]/div[3]/table/tbody/tr[25]/td')))
    
    #principal dimension
    LOA = wait.until(EC.visibility_of_element_located((By.XPATH,'/html/body/div/div/div[1]/div[3]/table/tbody/tr[45]/td')))
    T = wait.until(EC.visibility_of_element_located((By.XPATH,'/html/body/div/div/div[1]/div[3]/table/tbody/tr[40]/td')))
    
    dimensions = wait.until(EC.visibility_of_element_located((By.XPATH , '/html/body/div/div/div[1]/div[3]/table/tbody/tr[44]/td')))
    overall = str(dimensions.text)    
    split = overall.split('x')
    LPP, B, H = split
    
    #ship tonnage
    GT = wait.until(EC.visibility_of_element_located((By.XPATH,'/html/body/div/div/div[1]/div[3]/table/tbody/tr[31]/td')))
    NT = wait.until(EC.visibility_of_element_located((By.XPATH,'/html/body/div/div/div[1]/div[3]/table/tbody/tr[32]/td')))
    DWT = wait.until(EC.visibility_of_element_located((By.XPATH,'/html/body/div/div/div[1]/div[3]/table/tbody/tr[37]/td')))
    
    link = 'https://www.vesselfinder.com/vessels/details/{}'.format(IMO.text)
    
    # print variable names and value
#     print('NAME:', NAME.text)
#     print('REGISTER:', REGISTER.text)
#     print('IMO:', IMO.text)
#     print('VESSEL TYPE:', vessel_type.text)
#     print('LOA:', LOA.text)
#     print('LPP:', LPP)
#     print('T:', T.text)
#     print('B:', B)
#     print('H:', H)
#     print('GT:', GT.text)
#     print('NT:', NT.text)
#     print('DWT:', DWT.text)
#     print('LINK:', link)

# %%
# Define the fieldnames for the CSV file
fieldnames = ['NAME', 'REGISTER', 'IMO', 'TYPE', 'LOA', 'LPP', 'B', 'H', 'T',  'GT', 'NT', 'DWT', 'Link']

# %%
# Set up the webdriver
driver = webdriver.Chrome()

# Open the CSV file for writing
with open(write_path, mode='w', newline='') as details_file:
    writer = csv.DictWriter(details_file, fieldnames=fieldnames)
    writer.writeheader()
    
    # Open the input file and loop through each vessel name
    with open(read_path, newline='') as csvfile:
        reader = csv.reader(csvfile)        
        for row in reader:
            IMO = row[0]
            try:
                search(IMO)
                newtab()
                shipdata()
                print('ketemu IMO :',IMO.text)
            except:
                print('ga ketemu IMO :',IMO)
                continue
                
                           
            details_dict = {'NAME': NAME.text, 'REGISTER': REGISTER.text, 'IMO': IMO.text, 'TYPE':  vessel_type.text, 'LOA': LOA.text, 'LPP': LPP, 'B': B, 'H': H, 'T': T.text, 'GT': GT.text, 'NT': NT.text, 'DWT': DWT.text, 'Link': link}
            writer.writerow(details_dict)
# Out:
# ga ketemu IMO : IMO
# ga ketemu IMO : 9574626
# ga ketemu IMO : 9932103
# ga ketemu IMO : 8672653
# ga ketemu IMO : 9609665
# ga ketemu IMO : 9406104
# ga ketemu IMO : 9714226
# ga ketemu IMO : 9524815
# ga ketemu IMO : 8502547
# ga ketemu IMO : 9912440
# ga ketemu IMO : 9600011
# ga ketemu IMO : 9565259
# ga ketemu IMO : 9557460
# 169.400 x 26.000 x 13.600
# ketemu IMO : 9278923
# ga ketemu IMO : 9406037
# ga ketemu IMO : 9843857
# ga ketemu IMO : 8591744
# ga ketemu IMO : 8309866
# ga ketemu IMO : 9105463
# ga ketemu IMO : 8204731
# ga ketemu IMO : 9214264
# ga ketemu IMO : 9744764
# 179.990
# ga ketemu IMO : <selenium.webdriver.remote.webelement.WebElement (session="6d97d8c6010de9dc5831f4446c5f2e5a", element="f73e25e1-d490-4391-abaa-7f183ef79150")>
# ga ketemu IMO : 8316338
# ga ketemu IMO : 9180009
# ga ketemu IMO : 9218040
# ga ketemu IMO : 9611280
# ga ketemu IMO : 9671058
# ga ketemu IMO : 9509255
# ga ketemu IMO : 9312339
# ga ketemu IMO : 8598699
# ga ketemu IMO : 9499424
# ga ketemu IMO : 9110494
# ga ketemu IMO : 9154854
# ga ketemu IMO : 9124146
# ga ketemu IMO : 9671060
# ga ketemu IMO : 9263772
# ga ketemu IMO : 9753301
# ga ketemu IMO : 9145229
# ga ketemu IMO : 9561801
# ga ketemu IMO : 9708045
# ga ketemu IMO : 8554617
# ga ketemu IMO : 9685138
# ga ketemu IMO : 9123960
# ga ketemu IMO : 9923358
# ga ketemu IMO : 8357356
# ga ketemu IMO : 9303364
# ga ketemu IMO : 9637430
# ga ketemu IMO : 8416176
# ga ketemu IMO : 8715338
# ga ketemu IMO : 9791030
# ga ketemu IMO : 9838436
# ga ketemu IMO : 8734920
# ga ketemu IMO : 9647887
# ga ketemu IMO : 9570503
# ga ketemu IMO : 8601317
# ga ketemu IMO : 9498250
# ga ketemu IMO : 9193862
# ga ketemu IMO : 9333498
# ga ketemu IMO : 9769697
# ga ketemu IMO : 9498286
# ga ketemu IMO : 9460265
# ga ketemu IMO : 9748409
# ga ketemu IMO : 9559705
# ga ketemu IMO : 9108910
# ga ketemu IMO : 9558139
# ga ketemu IMO : 8726155
# ga ketemu IMO : 9250696
# ga ketemu IMO : 9715684
# ga ketemu IMO : 8126783
# ga ketemu IMO : 9554121
# ga ketemu IMO : 9638434
# ga ketemu IMO : 7433684
# ga ketemu IMO : 8671609
# ga ketemu IMO : 8308989
# ga ketemu IMO : 9259575
# ga ketemu IMO : 9621869
# ga ketemu IMO : 9665281
# ga ketemu IMO : 9586447
# ga ketemu IMO : 9498262
# ga ketemu IMO : 9422378
# ga ketemu IMO : 9725691
# ga ketemu IMO : 9550199
# ga ketemu IMO : 9250701
# ga ketemu IMO : 9605102
# ga ketemu IMO : 9550137
# ga ketemu IMO : 9406049
# ga ketemu IMO : 9656711
# ga ketemu IMO : 9643726
# ga ketemu IMO : 8128640
# ga ketemu IMO : 9528861
# ga ketemu IMO : 9860271
# ga ketemu IMO : 8671415
# ga ketemu IMO : 9497191
# ga ketemu IMO : 8502810
# ga ketemu IMO : 9505431
# ga ketemu IMO : 9660126
# ga ketemu IMO : 9151383
# ga ketemu IMO : 9588366
# ga ketemu IMO : 9712462
# ga ketemu IMO : 9230000
# ga ketemu IMO : 9580326
# ga ketemu IMO : 9725512
# ga ketemu IMO : 9255191
# ga ketemu IMO : 9831531
# ga ketemu IMO : 9649108
# ga ketemu IMO : 8863604
# ga ketemu IMO : 8701911
# ga ketemu IMO : 8915732
# ga ketemu IMO : 9759666
# ga ketemu IMO : 9205926
# ga ketemu IMO : 9104495
# ga ketemu IMO : 9579391
# ga ketemu IMO : 9550292
# ga ketemu IMO : 9578177
# ga ketemu IMO : 9545510
# ga ketemu IMO : 9218038
# ga ketemu IMO : 9624172
# ga ketemu IMO : 8403155
# ga ketemu IMO : 8507509
# ga ketemu IMO : 9412945
# ga ketemu IMO : 9851335
# ga ketemu IMO : 9580120
# ga ketemu IMO : 9584190
# ga ketemu IMO : 9727376
# ga ketemu IMO : 8322923
# ga ketemu IMO : 8917998
# ga ketemu IMO : 9590955
# ga ketemu IMO : 9298428
# ga ketemu IMO : 9364837
# ga ketemu IMO : 9172105
# ga ketemu IMO : 9334715
# ga ketemu IMO : 9267170
# ga ketemu IMO : 8908583
# ga ketemu IMO : 9406099
# ga ketemu IMO : 9261750
# ga ketemu IMO : 9861172
# ga ketemu IMO : 9621039
# ga ketemu IMO : 9350056
# ga ketemu IMO : 9637143
# ga ketemu IMO : 9736391
# ga ketemu IMO : 9545053
# ga ketemu IMO : 8672677
# ga ketemu IMO : 9577599
# ga ketemu IMO : 8508577
# ga ketemu IMO : 9317743
# ga ketemu IMO : 8400971
# ga ketemu IMO : 9270907
# ga ketemu IMO : 9464821
# ga ketemu IMO : 9062300
# ga ketemu IMO : 9197882
# ga ketemu IMO : 9596026
# ga ketemu IMO : 9754202
# ga ketemu IMO : 8671403
# ga ketemu IMO : 9125217
# ga ketemu IMO : 9464522
# ga ketemu IMO : 8422163
# ga ketemu IMO : 9424106
# ga ketemu IMO : 9517551
# ga ketemu IMO : 9528005
# ga ketemu IMO : 9628568
# ga ketemu IMO : 9818802
# ga ketemu IMO : 9535486
# ga ketemu IMO : 8201351
# ga ketemu IMO : 8413526
# ga ketemu IMO : 9635468
# ga ketemu IMO : 8671611
# ga ketemu IMO : 9078335
# ga ketemu IMO : 9785122
# ga ketemu IMO : 9690896
# ga ketemu IMO : 9595204
# ga ketemu IMO : 8403143
# ga ketemu IMO : 8300523
# ga ketemu IMO : 9239458
# ga ketemu IMO : 9316969
# ga ketemu IMO : 9474280
# ga ketemu IMO : 9643790
# ga ketemu IMO : 9506100
# ga ketemu IMO : 9833527
# ga ketemu IMO : 9127954
# ga ketemu IMO : 9607590
# ga ketemu IMO : 9753272
# ga ketemu IMO : 9592836
# ga ketemu IMO : 8407515
# ga ketemu IMO : 8505329
# ga ketemu IMO : 9244087
# ga ketemu IMO : 9299965
# ga ketemu IMO : 9498236
# ga ketemu IMO : 9221633
# ga ketemu IMO : 9052329
# ga ketemu IMO : 9619294
# ga ketemu IMO : 9575981
# ga ketemu IMO : 9132662
# ga ketemu IMO : 9449508
# ga ketemu IMO : 9019030
# ga ketemu IMO : 9597434
# ga ketemu IMO : 9297917
# ga ketemu IMO : 9719379
# ga ketemu IMO : 8315102
# ga ketemu IMO : 9136541
# ga ketemu IMO : 9599016
# ga ketemu IMO : 9322736
# ga ketemu IMO : 9127942
# ga ketemu IMO : 9987108
# ga ketemu IMO : 8112988
# ga ketemu IMO : 9267089
# ga ketemu IMO : 9719355
# ga ketemu IMO : 9044920
# ga ketemu IMO : 9580015
# ga ketemu IMO : 8510934
# ga ketemu IMO : 9551375
# ga ketemu IMO : 9489821
# ga ketemu IMO : 8512073
# ga ketemu IMO : 9485904
# ga ketemu IMO : 9345635
# ga ketemu IMO : 9034626
# ga ketemu IMO : 8671910
# ga ketemu IMO : 9190004
# ga ketemu IMO : 8913203
# ga ketemu IMO : 9579327
# ga ketemu IMO : 9205897
# ga ketemu IMO : 8671374
# ga ketemu IMO : 8323410
# ga ketemu IMO : 9548457
# ga ketemu IMO : 9577630
# ga ketemu IMO : 9285419
# ga ketemu IMO : 9573919
# ga ketemu IMO : 9464003
# ga ketemu IMO : 9866732
# ga ketemu IMO : 9754094
# ga ketemu IMO : 9118226
# ga ketemu IMO : 9244037
# ga ketemu IMO : 8517994
# ga ketemu IMO : 9476068
# ga ketemu IMO : 9132674
# ga ketemu IMO : 9519224
# ga ketemu IMO : 9584231
# ga ketemu IMO : 9594389
# ga ketemu IMO : 9454125
# ga ketemu IMO : 8500496
# ga ketemu IMO : 9911977
# ga ketemu IMO : 9905502
# ga ketemu IMO : 9863405
# ga ketemu IMO : 8701519
# ga ketemu IMO : 9416446
# ga ketemu IMO : 3560752
# ga ketemu IMO : 9455179
# ga ketemu IMO : 9250567
# ga ketemu IMO : 9637131
# ga ketemu IMO : 9791925
# ga ketemu IMO : 9072410
# ga ketemu IMO : 9250945
# ga ketemu IMO : 9610195
# ga ketemu IMO : 9962823
# ga ketemu IMO : 9338539
# ga ketemu IMO : 9650858
# ga ketemu IMO : 9044011
# ga ketemu IMO : 9343065
# ga ketemu IMO : 9561904
# ga ketemu IMO : 9738727
# ga ketemu IMO : 9715696
# ga ketemu IMO : 9866548
# ga ketemu IMO : 8914233
# ga ketemu IMO : 8671659
# ga ketemu IMO : 9636943
# ga ketemu IMO : 8741533
# ga ketemu IMO : 8223555
# ga ketemu IMO : 9618006
# ga ketemu IMO : 8512932
# ga ketemu IMO : 9437505
# ga ketemu IMO : 9606821
# ga ketemu IMO : 8513429
# ga ketemu IMO : 9727508
# ga ketemu IMO : 9755294
# ga ketemu IMO : 8308886
# ga ketemu IMO : 9646027
# ga ketemu IMO : 9450727
# ga ketemu IMO : 9881158
# ga ketemu IMO : 8530116
# ga ketemu IMO : 9285134
# ga ketemu IMO : 9650664
# ga ketemu IMO : 9675561
# ga ketemu IMO : 9926063
# ga ketemu IMO : 9928451
# ga ketemu IMO : 9498315
# ga ketemu IMO : 9682887
# ga ketemu IMO : 9747053
# ga ketemu IMO : 8219322
# ga ketemu IMO : 8912522
# ga ketemu IMO : 9894612
# ga ketemu IMO : 9320312
# ga ketemu IMO : 8502559
# ga ketemu IMO : 9464558
# ga ketemu IMO : 9927005
# ga ketemu IMO : 8507535
# ga ketemu IMO : 9135482
# ga ketemu IMO : 8308915
# ga ketemu IMO : 9791884
# ga ketemu IMO : 8671752
# ga ketemu IMO : 9610212
# ga ketemu IMO : 9565132
# ga ketemu IMO : 8511574
# ga ketemu IMO : 9823936
# ga ketemu IMO : 8311168
# ga ketemu IMO : 9709221
# ga ketemu IMO : 9806316
# ga ketemu IMO : 9133771
# ga ketemu IMO : 9379648
# ga ketemu IMO : 8671673
# ga ketemu IMO : 9146118
# ga ketemu IMO : 9118563
# ga ketemu IMO : 9591076
# ga ketemu IMO : 8521012
# ga ketemu IMO : 9609689
# ga ketemu IMO : 9865233
# ga ketemu IMO : 9838462
# ga ketemu IMO : 9414474
# ga ketemu IMO : 9792905
# ga ketemu IMO : 9159737
# ga ketemu IMO : 8418734
# ga ketemu IMO : 9574183
# ga ketemu IMO : 9726190
# ga ketemu IMO : 9631216
# ga ketemu IMO : 8672093
# ga ketemu IMO : 9766188
# ga ketemu IMO : 9517331
# ga ketemu IMO : 9846160
# ga ketemu IMO : 9437529
# ga ketemu IMO : 9580091
# ga ketemu IMO : 9561825
# ga ketemu IMO : 9496264
# ga ketemu IMO : 8405804
# ga ketemu IMO : 9659921
# ga ketemu IMO : 9675717
# ga ketemu IMO : 8318817
# ga ketemu IMO : 9583691
# ga ketemu IMO : 9697961
# ga ketemu IMO : 9467914
# ga ketemu IMO : 9191565
# ga ketemu IMO : 9216597
# ga ketemu IMO : 9506332
# ga ketemu IMO : 9663738
# ga ketemu IMO : 9385221
# ga ketemu IMO : 9133290
# ga ketemu IMO : 9056387
# ga ketemu IMO : 9487500
# ga ketemu IMO : 9624330
# ga ketemu IMO : 9793820
# ga ketemu IMO : 8671843
# ga ketemu IMO : 8412508
# ga ketemu IMO : 9600607
# ga ketemu IMO : 9561796
# ga ketemu IMO : 9288540
# ga ketemu IMO : 9957191
# ga ketemu IMO : 9072422
# ga ketemu IMO : 9707742
# ga ketemu IMO : 9253404
# ga ketemu IMO : 8212087
# ga ketemu IMO : 9897975
# ga ketemu IMO : 9074781
# ga ketemu IMO : 9428152
# ga ketemu IMO : 9496939
# ga ketemu IMO : 8827466
# ga ketemu IMO : 9832509
# ga ketemu IMO : 9855410
# ga ketemu IMO : 9393151
# ga ketemu IMO : 7713125
# ga ketemu IMO : 9671084
# ga ketemu IMO : 8407424
# ga ketemu IMO : 8902474
# ga ketemu IMO : 9674385
# ga ketemu IMO : 9563380
# ga ketemu IMO : 9686338
# ga ketemu IMO : 9649110
# ga ketemu IMO : 9483700
# ga ketemu IMO : 9503744
# ga ketemu IMO : 9114488
# ga ketemu IMO : 8604369
# ga ketemu IMO : 9742998
# ga ketemu IMO : 8806852
# ga ketemu IMO : 9713832
# ga ketemu IMO : 9646730
# ga ketemu IMO : 9032056
# ga ketemu IMO : 9612155
# ga ketemu IMO : 9631694
# ga ketemu IMO : 9992452
# ga ketemu IMO : 9646704
# ga ketemu IMO : 9768954
# ga ketemu IMO : 9574030
# ga ketemu IMO : 9738741
# ga ketemu IMO : 9943554
# ga ketemu IMO : 9621728
# ga ketemu IMO : 9820996
# ga ketemu IMO : 9571777
# ga ketemu IMO : 9648104
# ga ketemu IMO : 9709324
# ga ketemu IMO : 9400588
# ga ketemu IMO : 9486403
# ga ketemu IMO : 9845984
# ga ketemu IMO : 8914738
# ga ketemu IMO : 9218052
# ga ketemu IMO : 9860609
# ga ketemu IMO : 9522738
# ga ketemu IMO : 9583847
# ga ketemu IMO : 9697844
# ga ketemu IMO : 8323214
# ga ketemu IMO : 9753284
# ga ketemu IMO : 9662370
# ga ketemu IMO : 9522910
# ga ketemu IMO : 9278741
# ga ketemu IMO : 8860822
# ga ketemu IMO : 9521899
# ga ketemu IMO : 9444912
# ga ketemu IMO : 9110341
# ga ketemu IMO : 8671726
# ga ketemu IMO : 9754836
# ga ketemu IMO : 9841756
# ga ketemu IMO : 8518651
# ga ketemu IMO : 9843895
# ga ketemu IMO : 9611503
# ga ketemu IMO : 9474242
# ga ketemu IMO : 9515101
# ga ketemu IMO : 9358371
# ga ketemu IMO : 9084267
# ga ketemu IMO : 8915304
# ga ketemu IMO : 9357444
# ga ketemu IMO : 9181508
# ga ketemu IMO : 9595254
# ga ketemu IMO : 9706372
# ga ketemu IMO : 8671740
# ga ketemu IMO : 8306838
# ga ketemu IMO : 9180011
# ga ketemu IMO : 9493236
# ga ketemu IMO : 9506356
# ga ketemu IMO : 9052721
# ga ketemu IMO : 9561813
# ga ketemu IMO : 9413925
# ga ketemu IMO : 9673563
# ga ketemu IMO : 9691498
# ga ketemu IMO : 9897949
# ga ketemu IMO : 9424302
# ga ketemu IMO : 9694854
# ga ketemu IMO : 9643453
# ga ketemu IMO : 9896189
# ga ketemu IMO : 8308068
# ga ketemu IMO : 9060730
# ga ketemu IMO : 9649885
# ga ketemu IMO : 9545508
# ga ketemu IMO : 9590785
# ga ketemu IMO : 8515843
# ga ketemu IMO : 9312327
# ga ketemu IMO : 9200574
# ga ketemu IMO : 8357136
# ga ketemu IMO : 9350082
# ga ketemu IMO : 9282613
# ga ketemu IMO : 9248198
# ga ketemu IMO : 9615030
# ga ketemu IMO : 8223567
# ga ketemu IMO : 9464948
# ga ketemu IMO : 9392248
# ga ketemu IMO : 9533775
# ga ketemu IMO : 8309115
# ga ketemu IMO : 9551844
# ga ketemu IMO : 9138692
# ga ketemu IMO : 9522922
# ga ketemu IMO : 9864887
# ga ketemu IMO : 8309725
# ga ketemu IMO : 8404874
# ga ketemu IMO : 9913999
# ga ketemu IMO : 9585015
# ga ketemu IMO : 8671520
# ga ketemu IMO : 9860611
# ga ketemu IMO : 9060235
# ga ketemu IMO : 9801263
# ga ketemu IMO : 9502788
# ga ketemu IMO : 9222558
# ga ketemu IMO : 8412766
# ga ketemu IMO : 9311426
# ga ketemu IMO : 9611292
# ga ketemu IMO : 9519169
# ga ketemu IMO : 9595979
# ga ketemu IMO : 8412936
# ga ketemu IMO : 8355530
# ga ketemu IMO : 8537243
# ga ketemu IMO : 9695640
# ga ketemu IMO : 9909663
# ga ketemu IMO : 9267857
# ga ketemu IMO : 8653073
# ga ketemu IMO : 9710086
# ga ketemu IMO : 9109512
# ga ketemu IMO : 9586916
# ga ketemu IMO : 9626601
# ga ketemu IMO : 9522829
# ga ketemu IMO : 8306852
# ga ketemu IMO : 8400244
# ga ketemu IMO : 9157428
# ga ketemu IMO : 9792888
# ga ketemu IMO : 9218404
# ga ketemu IMO : 9557214
# ga ketemu IMO : 9708928
# ga ketemu IMO : 9243693

# %%
# Set up the webdriver
driver = webdriver.Chrome()

driver.get("https://www.classnk.com/register/regships/regships.aspx")

IMO = '9278923'
search(IMO)
newtab()
shipdata()
print('yahalo')
# Out:
# 169.400 x 26.000 x 13.600
# yahalo

# %%
# Set up the webdriver
driver = webdriver.Chrome()

driver.get("https://www.classnk.com/register/regships/regships.aspx")

IMO = '9317456'

time.sleep(5)
search_field = driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div/div[3]/div/form/div[3]/table/tbody/tr[2]/td/input')
search_field.send_keys(IMO)

search_button = driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div/div[3]/div/form/div[3]/p/a[1]')
search_button.click()

time.sleep(2)
ship_button = driver.find_element(By.XPATH, '/html/body/div[2]/div/div/div/div[3]/div/div[1]/div[2]/h3/a')
ship_button.click()

# Open a new tab with the desired URL
driver.execute_script("window.open('https://www.classnk.com/register/regships/one.aspx', '_blank');")

# Switch to the new tab
driver.switch_to.window(driver.window_handles[-1])

time.sleep(5)
name = driver.find_element(By.XPATH, '/html/body/div/div/div[1]/div[3]/table/tbody/tr[8]/td')
print(name.text)
# Out:
# AGRI KINSALE
