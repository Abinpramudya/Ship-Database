# %%
import os
import time
import csv
import re
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import NoSuchElementException

# %%
#edit sesuai kebutuhan
vessel_type = 'bulk carrier'
filenum = 'bulkcarrier'
kelas = 'BKI'

# %%
#directory file csv
read_path = 'C:/Users/abinp/Documents/ITS/side projects/new/ship data scrapping/input/{}/{}.csv'.format(vessel_type,filenum)
write_path = 'C:/Users/abinp/Documents/ITS/side projects/new/ship data scrapping/output/{}/{}/{}.csv'.format(kelas,vessel_type,filenum)

# %%
# Check if input file exists
if os.path.exists(read_path):
    print(f"CSV read file is found, continuing...")
else:
    print(f"CSV read file is not found")
    print('exiting....')
    
# Check if output file exists and create it if necessary
if os.path.exists(write_path):
    print(f"CSV write file  is found, continuing...")
else:
    print(f"CSV write file is not found, creating one...")
    os.makedirs(os.path.dirname(write_path), exist_ok=True) # Create output directory if it doesn't exist
    with open(write_path, 'w', newline='') as f:
        writer = csv.writer(f)
# Out:
# CSV read file is found, continuing...
# CSV write file  is found, continuing...

# %%
driver = webdriver.Chrome(executable_path=r"chromedriver")
driver.get("https://www.bki.co.id/shipregister.html")

# %%
#function search di website bki
def search(name):
    vessel_name = name
    search_field = driver.find_element(By.XPATH, '/html/body/div/div/div/div/div/div/div/div[2]/form/input')
    search_field.send_keys(vessel_name)
    search_field.send_keys(Keys.RETURN)

# %%
#function click di website bki
def click():
    first_vessel = driver.find_element(By.XPATH, '/html/body/div/div/div/div/div/div/div/div[2]/table/tbody[2]/tr/td[1]/a')
    first_vessel.click()
    
def hull():
    hull_data = driver.find_element(By.XPATH, '/html/body/div/div/div/div/div/div/div[2]/button[2]')
    hull_data.click()

# %%
#roman numeral function
def roman_numeral(n):
    roman_map = {1: 'I', 2: 'II', 3: 'III', 4: 'IV', 5: 'V', 6: 'VI', 7: 'VII', 8: 'VIII', 9: 'IX'}
    return roman_map[n] if n in roman_map else str(n)

# function iterasi nama
def process_ship_name(name, iteration):
    global vessel_name

    if iteration == 1:
        # Replace single number with Roman numeral equivalent
        name = re.sub(r'\b(\d)\b', lambda match: roman_numeral(int(match.group(1))), name)
        name = re.sub(r'^MV\.', '', name)
        
    elif iteration == 2:
        name = re.sub(r'(\D)(\d)$', r'\1 \2', name) 
    
    elif iteration == 3:
        if len(re.findall(r'\d', name)) == 1:
            name = re.sub(r'(\D)(\d)$', r'\1 0\2', name)
            name = re.sub(r'\s+', ' ', name)  # remove multiple spaces
   
    elif iteration == 4:
        name = re.sub(r'\d', '', name)
    
    vessel_name = name.strip()
#     print(vessel_name)

process_ship_name('CAHAYA MUSTIKA LAUT1',4)

# %%
#data mining di website
def shipdata():
    global LOA , LPP , B , H , T
    global DWT , NT , GT , LT
    global NAME , REGISTER , IMO , status, type
    global link
    
    NAME = driver.find_element(By.XPATH,'/html/body/div/div/div/div/div/div/div[1]/table/tbody[2]/tr/td[1]/b')
    REGISTER = driver.find_element(By.XPATH,'/html/body/div/div/div/div/div/div/div[1]/table/tbody[2]/tr/td[2]/b')
    IMO = driver.find_element(By.XPATH,'/html/body/div/div/div/div/div/div/div[1]/table/tbody[2]/tr/td[3]/b')
    status = driver.find_element(By.XPATH,'/html/body/div/div/div/div/div/div/div[1]/table/tbody[2]/tr/td[4]/b')
    
    #principal dimension
    LOA = driver.find_element(By.XPATH,'/html/body/div/div/div/div/div/div/div[4]/table/tbody/tr[3]/td[1]/table/tbody/tr/td[1]/b')
    LPP = driver.find_element(By.XPATH,'/html/body/div/div/div/div/div/div/div[4]/table/tbody/tr[3]/td[1]/table/tbody/tr/td[2]/b')
    B = driver.find_element(By.XPATH,'/html/body/div/div/div/div/div/div/div[4]/table/tbody/tr[3]/td[1]/table/tbody/tr/td[3]/b')
    H = driver.find_element(By.XPATH,'/html/body/div/div/div/div/div/div/div[4]/table/tbody/tr[3]/td[1]/table/tbody/tr/td[4]/b')
    T = driver.find_element(By.XPATH,'/html/body/div/div/div/div/div/div/div[4]/table/tbody/tr[4]/td[3]')
    
    #ship tonnage
    LT = driver.find_element(By.XPATH,'/html/body/div/div/div/div/div/div/div[4]/table/tbody/tr[3]/td[2]/table/tbody/tr/td[1]/b')
    GT = driver.find_element(By.XPATH,'/html/body/div/div/div/div/div/div/div[4]/table/tbody/tr[3]/td[2]/table/tbody/tr/td[2]/b')
    NT = driver.find_element(By.XPATH,'/html/body/div/div/div/div/div/div/div[4]/table/tbody/tr[3]/td[2]/table/tbody/tr/td[3]/b')
    DWT = driver.find_element(By.XPATH,'/html/body/div/div/div/div/div/div/div[4]/table/tbody/tr[3]/td[2]/table/tbody/tr/td[4]/b')
    
    link = 'https://www.bki.co.id/shipregister-{}.html'.format(REGISTER.text)
    # print variable names and value

# %%
# Define the fieldnames for the CSV file
fieldnames = ['NAME', 'REGISTER', 'IMO', 'status', 'LOA', 'LPP', 'B', 'H', 'T', 'LT', 'GT', 'NT', 'DWT', 'Link']

# %%
# Set up the webdriver
driver = webdriver.Chrome()

driver.get("https://www.bki.co.id/shipregister.html")

# Open the CSV file for writing
with open(write_path, mode='w', newline='') as details_file:
    writer = csv.DictWriter(details_file, fieldnames=fieldnames)
    writer.writeheader()
    
    # Open the input file and loop through each vessel name
    with open(read_path, newline='') as csvfile:
        reader = csv.reader(csvfile)        
        for row in reader:
            vessel_name = row[0]
            driver.get("https://www.bki.co.id/shipregister.html")

            try:
                search(vessel_name)
                click()
                hull()
                shipdata()
            except:
                try:
                    print('mencoba pergantian iterasi 1')
                    process_ship_name(vessel_name, 1)
                    search(vessel_name)
                    click()
                    hull()
                    shipdata()

                except:
                    try:
                        print('mencoba pergantian iterasi 2')
                        process_ship_name(vessel_name, 2)
                        search(vessel_name)
                        click()
                        hull()
                        shipdata()

                    except:
                        try:
                            print('mencoba pergantian iterasi 3')
                            process_ship_name(vessel_name, 3)
                            search(vessel_name)
                            click()
                            hull()
                            shipdata()

                        except:
                            try:
                                print('mencoba pergantian iterasi 4')
                                process_ship_name(vessel_name, 4)
                                search(vessel_name)
                                click()
                                hull()
                                shipdata()
                            except:
                                print('emang kapalnya gaada di bki')
                                continue
                                
                try:                
                    details_dict = {'NAME': NAME.text, 'REGISTER': REGISTER.text, 'IMO': IMO.text, 'status': status.text, 'LOA': LOA.text, 'LPP': LPP.text, 'B': B.text, 'H': H.text, 'T': T.text, 'LT': LT.text, 'GT': GT.text, 'NT': NT.text, 'DWT': DWT.text, 'Link': link}
                    writer.writerow(details_dict)
                except:
                    continue
# Out:
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# NAME: PUSRI INDONESIA I
# REGISTER: 19614
# IMO: 9711640
# status: AKTIF (ACTIVE)
# LOA: 134.00
# LPP: 131.60
# B: 26.40
# H: 11.00
# T: 0.00
# LT: 5614
# GT: 12454
# NT: 5970
# DWT: 0
# Link:  https://www.bki.co.id/shipregister-19614.html
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# NAME: KARUNIA PRATAMA 1
# REGISTER: 11077
# IMO: 8732348
# status: AKTIF (ACTIVE)
# LOA: 30.00
# LPP: 28.00
# B: 9.60
# H: 4.50
# T: 0.00
# LT: 808
# GT: 280
# NT: 84
# DWT: 0
# Link:  https://www.bki.co.id/shipregister-11077.html
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# NAME: DK 02
# REGISTER: 20917
# IMO: 9154555
# status: AKTIF (ACTIVE)
# LOA: 185.73
# LPP: 177.00
# B: 30.95
# H: 16.40
# T: 11.77
# LT: 4658
# GT: 25807
# NT: 16061
# DWT: 0
# Link:  https://www.bki.co.id/shipregister-20917.html
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# NAME: CAHAYA MUSTIKA LAUT 01
# REGISTER: 23132
# IMO: 9128805
# status: AKTIF (ACTIVE)
# LOA: 154.35
# LPP: 146.00
# B: 26.00
# H: 13.35
# T: 0.00
# LT: 3867
# GT: 15485
# NT: 8587
# DWT: 0
# Link:  https://www.bki.co.id/shipregister-23132.html
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# NAME: KT 06
# REGISTER: 22023
# IMO: 9100396
# status: DICABUT (WITHDRAWN)
# LOA: 189.83
# LPP: 179.80
# B: 31.00
# H: 16.50
# T: 11.66
# LT: 4882
# GT: 25943
# NT: 15480
# DWT: 0
# Link:  https://www.bki.co.id/shipregister-22023.html
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# NAME: CHLOE 03
# REGISTER: 10253
# IMO: 9093567
# status: AKTIF (ACTIVE)
# LOA: 29.00
# LPP: 26.85
# B: 8.00
# H: 3.70
# T: 3.10
# LT: 594
# GT: 216
# NT: 65
# DWT: 0
# Link:  https://www.bki.co.id/shipregister-10253.html
# NAME: SAMUDRA SAKTI III
# REGISTER: 25207
# IMO: 9320295
# status: AKTIF (ACTIVE)
# LOA: 178.70
# LPP: 170.00
# B: 28.00
# H: 14.00
# T:
# LT:
# GT: 19918
# NT: 10492
# DWT: 30634
# Link:  https://www.bki.co.id/shipregister-25207.html
# NAME: KT 02
# REGISTER: 21531
# IMO: 9154608
# status: DICABUT (WITHDRAWN)
# LOA: 185.74
# LPP: 177.00
# B: 30.40
# H: 16.50
# T: 11.95
# LT: 5748
# GT: 25982
# NT: 15690
# DWT: 0
# Link:  https://www.bki.co.id/shipregister-21531.html
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# NAME: FIRST KASIH
# REGISTER: 13425
# IMO: 9071727
# status: DICABUT (WITHDRAWN)
# LOA: 216.00
# LPP: 201.67
# B: 31.80
# H: 16.95
# T: 12.30
# LT: 4050
# GT: 31357
# NT: 16711
# DWT: 52580
# Link:  https://www.bki.co.id/shipregister-13425.html
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# NAME: KT 05
# REGISTER: 21571
# IMO: 9154610
# status: DICABUT (WITHDRAWN)
# LOA: 185.74
# LPP: 177.00
# B: 30.40
# H: 16.50
# T: 11.62
# LT: 4655
# GT: 25982
# NT: 15690
# DWT: 0
# Link:  https://www.bki.co.id/shipregister-21571.html
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# NAME: PANCARAN II 1615
# REGISTER: 18069
# IMO: 8691087
# status: AKTIF (ACTIVE)
# LOA: 23.50
# LPP: 21.65
# B: 7.32
# H: 3.20
# T: 2.69
# LT: 508
# GT: 155
# NT: 47
# DWT: 0
# Link:  https://www.bki.co.id/shipregister-18069.html
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# NAME: SRIKANDI INDONESIA
# REGISTER: 21462
# IMO: 9164823
# status: DITANGGUHKAN (SUSPEND)
# LOA: 157.90
# LPP: 149.00
# B: 23.13
# H: 13.80
# T: 0.00
# LT: 4118
# GT: 14118
# NT: 6124
# DWT: 0
# Link:  https://www.bki.co.id/shipregister-21462.html
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# NAME: MANALAGI TARA
# REGISTER: 25193
# IMO: 9330422
# status: AKTIF (ACTIVE)
# LOA: 189.99
# LPP: 183.04
# B: 32.26
# H: 17.20
# T:
# LT:
# GT: 31273
# NT: 18267
# DWT: 53608
# Link:  https://www.bki.co.id/shipregister-25193.html
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# NAME: ISA EXPRESS
# REGISTER: 17238
# IMO: 9082752
# status: DITANGGUHKAN (SUSPEND)
# LOA: 185.74
# LPP: 178.08
# B: 30.40
# H: 16.50
# T: 0.00
# LT: 4917
# GT: 26059
# NT: 14880
# DWT: 0
# Link:  https://www.bki.co.id/shipregister-17238.html
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# NAME: ISA GOLDEN
# REGISTER: 25319
# IMO: 9116292
# status: AKTIF (ACTIVE)
# LOA: 166.00
# LPP: 158.68
# B: 27.00
# H: 14.40
# T:
# LT:
# GT: 18306
# NT: 9071
# DWT: 0
# Link:  https://www.bki.co.id/shipregister-25319.html
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# NAME: SURYAWATI
# REGISTER: 10446
# IMO: 9159191
# status: DICABUT (WITHDRAWN)
# LOA: 224.96
# LPP: 215.00
# B: 32.20
# H: 18.30
# T: 13.29
# LT: 5043
# GT: 36175
# NT: 23550
# DWT: 69124
# Link:  https://www.bki.co.id/shipregister-10446.html
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# NAME: TITAN 41
# REGISTER: 17565
# IMO: 0
# status: DICABUT (WITHDRAWN)
# LOA: 83.80
# LPP: 80.33
# B: 13.80
# H: 3.88
# T: 2.80
# LT: 1388
# GT: 1635
# NT: 1184
# DWT: 2024
# Link:  https://www.bki.co.id/shipregister-17565.html
# NAME: FORUM
# REGISTER: 24214
# IMO: 9214850
# status: AKTIF (ACTIVE)
# LOA: 183.04
# LPP: 174.30
# B: 31.00
# H: 16.47
# T:
# LT: 4840
# GT: 26038
# NT: 15862
# DWT: 0
# Link:  https://www.bki.co.id/shipregister-24214.html
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# NAME: GEMARA SATU
# REGISTER: 920
# IMO: 7609805
# status: DICABUT (WITHDRAWN)
# LOA: 0.00
# LPP: 0.00
# B: 0.00
# H: 0.00
# T: 0.00
# LT: 0
# GT: 147
# NT: 0
# DWT: 0
# Link:  https://www.bki.co.id/shipregister-920.html
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# NAME: PACIFIC BULK
# REGISTER: 23875
# IMO: 9237137
# status: AKTIF (ACTIVE)
# LOA: 189.80
# LPP: 181.00
# B: 32.26
# H: 16.90
# T:
# LT: 5018
# GT: 27986
# NT: 17077
# DWT: 0
# Link:  https://www.bki.co.id/shipregister-23875.html
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# NAME: ADHIGUNA TARAHAN
# REGISTER: 3856
# IMO: 8324232
# status: AKTIF (ACTIVE)
# LOA: 149.35
# LPP: 143.50
# B: 21.00
# H: 13.20
# T: 6.41
# LT: 6828
# GT: 12416
# NT: 3725
# DWT: 11096
# Link:  https://www.bki.co.id/shipregister-3856.html
# NAME: MANALAGI ASTI
# REGISTER: 25091
# IMO: 9200665
# status: AKTIF (ACTIVE)
# LOA: 235.70
# LPP: 232.18
# B: 38.00
# H: 19.40
# T:
# LT:
# GT: 49565
# NT: 29067
# DWT: 0
# Link:  https://www.bki.co.id/shipregister-25091.html
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# NAME: SARASWATI
# REGISTER: 6437
# IMO: 8500173
# status: DICABUT (WITHDRAWN)
# LOA: 175.00
# LPP: 165.00
# B: 27.80
# H: 16.00
# T: 0.00
# LT: 6570
# GT: 20643
# NT: 6193
# DWT: 27547
# Link:  https://www.bki.co.id/shipregister-6437.html
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# NAME: HI 01
# REGISTER: 21947
# IMO: 9003184
# status: DICABUT (WITHDRAWN)
# LOA: 179.99
# LPP: 172.00
# B: 30.50
# H: 15.80
# T: 10.70
# LT: 4610
# GT: 23300
# NT: 13707
# DWT: 0
# Link:  https://www.bki.co.id/shipregister-21947.html
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# NAME: TAMARK 01
# REGISTER: 24891
# IMO:
# status: AKTIF (ACTIVE)
# LOA: 59.98
# LPP: 58.50
# B: 12.50
# H: 2.95
# T:
# LT:
# GT: 826
# NT: 309
# DWT: 0
# Link:  https://www.bki.co.id/shipregister-24891.html
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# NAME: ARK AMETHYST
# REGISTER: 18825
# IMO: 0
# status: DICABUT (WITHDRAWN)
# LOA: 91.50
# LPP: 87.96
# B: 24.40
# H: 5.50
# T: 0.00
# LT: 1225
# GT: 3065
# NT: 919
# DWT: 0
# Link:  https://www.bki.co.id/shipregister-18825.html
# NAME: LUMOSO PERMAI
# REGISTER: 21094
# IMO: 9106728
# status: AKTIF (ACTIVE)
# LOA: 188.33
# LPP: 179.50
# B: 31.00
# H: 16.30
# T: 11.37
# LT: 4967
# GT: 26040
# NT: 15499
# DWT: 0
# Link:  https://www.bki.co.id/shipregister-21094.html
# NAME: AURORA CHRISTINE
# REGISTER: 24063
# IMO: 9214862
# status: AKTIF (ACTIVE)
# LOA: 183.04
# LPP: 174.30
# B: 31.00
# H: 16.47
# T:
# LT: 4840
# GT: 26038
# NT: 15862
# DWT: 0
# Link:  https://www.bki.co.id/shipregister-24063.html
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# NAME: MANALAGI ASTA
# REGISTER: 25080
# IMO: 9200653
# status: AKTIF (ACTIVE)
# LOA: 235.70
# LPP: 232.18
# B: 38.00
# H: 19.40
# T:
# LT:
# GT: 49565
# NT: 29067
# DWT: 0
# Link:  https://www.bki.co.id/shipregister-25080.html
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# NAME: BERKAH 99
# REGISTER: 21555
# IMO: 9200457
# status: AKTIF (ACTIVE)
# LOA: 189.33
# LPP: 178.09
# B: 30.95
# H: 16.40
# T: 11.73
# LT: 4700
# GT: 26580
# NT: 16450
# DWT: 0
# Link:  https://www.bki.co.id/shipregister-21555.html
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# NAME: MANALAGI DASA
# REGISTER: 24929
# IMO: 9217668
# status: AKTIF (ACTIVE)
# LOA: 229.93
# LPP: 221.31
# B: 38.00
# H: 19.90
# T:
# LT:
# GT: 48029
# NT: 26236
# DWT: 0
# Link:  https://www.bki.co.id/shipregister-24929.html
# mencoba pergantian iterasi 1
# NAME: INTAN BARUNA
# REGISTER: 19016
# IMO: 9633018
# status: AKTIF (ACTIVE)
# LOA: 169.37
# LPP: 161.21
# B: 27.20
# H: 13.60
# T: 9.81
# LT: 3825
# GT: 17019
# NT: 10101
# DWT: 28387
# Link:  https://www.bki.co.id/shipregister-19016.html
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# NAME: HI 02
# REGISTER: 24198
# IMO: 9200550
# status: AKTIF (ACTIVE)
# LOA: 189.80
# LPP: 181.90
# B: 32.26
# H: 16.90
# T:
# LT: 5018
# GT: 27819
# NT: 16565
# DWT: 50249
# Link:  https://www.bki.co.id/shipregister-24198.html
# NAME: DEWI CITRAWATI
# REGISTER: 20915
# IMO: 8699364
# status: AKTIF (ACTIVE)
# LOA: 25.00
# LPP: 22.62
# B: 7.00
# H: 3.40
# T: 0.00
# LT: 608
# GT: 162
# NT: 79
# DWT: 0
# Link:  https://www.bki.co.id/shipregister-20915.html
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# NAME: TITAN 40
# REGISTER: 17613
# IMO: 0
# status: DICABUT (WITHDRAWN)
# LOA: 85.80
# LPP: 83.08
# B: 14.20
# H: 3.80
# T: 0.00
# LT: 1308
# GT: 1733
# NT: 468
# DWT: 0
# Link:  https://www.bki.co.id/shipregister-17613.html
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# NAME: ARLYNN
# REGISTER: 18005
# IMO: 8693607
# status: AKTIF (ACTIVE)
# LOA: 23.94
# LPP: 22.56
# B: 7.00
# H: 3.40
# T: 0.00
# LT: 608
# GT: 152
# NT: 46
# DWT: 0
# Link:  https://www.bki.co.id/shipregister-18005.html
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# NAME: MANALAGI SAMBA
# REGISTER: 25038
# IMO: 9254501
# status: AKTIF (ACTIVE)
# LOA: 189.99
# LPP: 182.87
# B: 32.26
# H: 17.00
# T:
# LT:
# GT: 30011
# NT: 17843
# DWT: 0
# Link:  https://www.bki.co.id/shipregister-25038.html
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# NAME: VICTORIA I
# REGISTER: 11447
# IMO: 0
# status: AKTIF (ACTIVE)
# LOA: 91.44
# LPP: 87.78
# B: 24.38
# H: 5.48
# T: 0.00
# LT: 1219
# GT: 3107
# NT: 933
# DWT: 0
# Link:  https://www.bki.co.id/shipregister-11447.html
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# NAME: AZZAHRA
# REGISTER: 17524
# IMO: 8309232
# status: DICABUT (WITHDRAWN)
# LOA: 189.50
# LPP: 181.98
# B: 30.00
# H: 15.70
# T: 10.97
# LT: 4746
# GT: 24943
# NT: 14024
# DWT: 42842
# Link:  https://www.bki.co.id/shipregister-17524.html
# NAME: KARTINI BARUNA
# REGISTER: 20003
# IMO: 9291107
# status: AKTIF (ACTIVE)
# LOA: 225.00
# LPP: 217.68
# B: 32.26
# H: 19.30
# T: 0.00
# LT: 5349
# GT: 38870
# NT: 25160
# DWT: 0
# Link:  https://www.bki.co.id/shipregister-20003.html
# mencoba pergantian iterasi 1
# NAME: GOLDEN DESTINY
# REGISTER: 24410
# IMO: 9252046
# status: DITANGGUHKAN (SUSPEND)
# LOA:
# LPP: 161.21
# B: 27.20
# H: 13.60
# T:
# LT: 3864
# GT: 17935
# NT: 10562
# DWT: 0
# Link:  https://www.bki.co.id/shipregister-24410.html
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# NAME: ZALEHA FITRAT
# REGISTER: 17825
# IMO: 8317019
# status: DICABUT (WITHDRAWN)
# LOA: 185.84
# LPP: 177.97
# B: 30.40
# H: 15.20
# T: 11.31
# LT: 4922
# GT: 26014
# NT: 13673
# DWT: 0
# Link:  https://www.bki.co.id/shipregister-17825.html
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# NAME: JHONI XLIX
# REGISTER: 24957
# IMO: 9590735
# status: AKTIF (ACTIVE)
# LOA: 169.37
# LPP: 161.21
# B: 27.20
# H: 13.60
# T:
# LT:
# GT: 17019
# NT: 10108
# DWT: 0
# Link:  https://www.bki.co.id/shipregister-24957.html
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# NAME: MALAHAYATI BARUNA
# REGISTER: 25712
# IMO: 9302839
# status: AKTIF (ACTIVE)
# LOA: 189.99
# LPP: 182.00
# B: 32.26
# H: 17.90
# T:
# LT:
# GT: 31226
# NT: 18824
# DWT: 49
# Link:  https://www.bki.co.id/shipregister-25712.html
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# NAME: DK 03
# REGISTER: 23787
# IMO: 9082908
# status: AKTIF (ACTIVE)
# LOA: 189.80
# LPP: 181.00
# B: 31.00
# H: 16.50
# T:
# LT: 4918
# GT: 27458
# NT: 15906
# DWT: 0
# Link:  https://www.bki.co.id/shipregister-23787.html
# NAME: ARFIANIE
# REGISTER: 21158
# IMO: 8316481
# status: DICABUT (WITHDRAWN)
# LOA: 188.87
# LPP: 181.00
# B: 30.00
# H: 15.70
# T: 0.00
# LT: 4762
# GT: 25227
# NT: 14040
# DWT: 0
# Link:  https://www.bki.co.id/shipregister-21158.html
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# NAME: BUHILA
# REGISTER: 202
# IMO: 0
# status: DICABUT (WITHDRAWN)
# LOA: 0.00
# LPP: 18.90
# B: 5.37
# H: 2.11
# T: 0.00
# LT: 650
# GT: 75
# NT: 23
# DWT: 0
# Link:  https://www.bki.co.id/shipregister-202.html
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# NAME: AMMARA SAGARA 368
# REGISTER: 23378
# IMO: 0
# status: AKTIF (ACTIVE)
# LOA: 36.58
# LPP: 36.58
# B: 12.19
# H: 2.44
# T: 0.00
# LT: 570
# GT: 271
# NT: 82
# DWT: 0
# Link:  https://www.bki.co.id/shipregister-23378.html
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# NAME: MANALAGI ENZI
# REGISTER: 24622
# IMO: 9217929
# status: AKTIF (ACTIVE)
# LOA: 189.90
# LPP: 180.00
# B: 32.20
# H: 16.80
# T:
# LT:
# GT: 28693
# NT: 16690
# DWT: 50363
# Link:  https://www.bki.co.id/shipregister-24622.html
# NAME: KASAMIRA
# REGISTER: 6686
# IMO: 8514629
# status: AKTIF (ACTIVE)
# LOA: 72.30
# LPP: 66.60
# B: 11.60
# H: 6.80
# T: 0.00
# LT: 1314
# GT: 1451
# NT: 562
# DWT: 1448
# Link:  https://www.bki.co.id/shipregister-6686.html
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki
# mencoba pergantian iterasi 1
# mencoba pergantian iterasi 2
# mencoba pergantian iterasi 3
# mencoba pergantian iterasi 4
# emang kapalnya gaada di bki

# %%
#GPT VERSION
# Set up the webdriver
driver = webdriver.Chrome()

driver.get("https://www.bki.co.id/shipregister.html")
vessel_name = 'KT 05'
search(vessel_name)


for i in range(1, 5):
    try:
        search(vessel_name)
        click()
        break
    except:
        print(f"mencoba pergantian iterasi {i}")
        process_ship_name(vessel_name, i)

# %%
# Set up the webdriver
driver = webdriver.Chrome()

driver.get("https://www.bki.co.id/shipregister.html")

# Open the CSV file for writing
with open(write_path, mode='w', newline='') as details_file:
    writer = csv.DictWriter(details_file, fieldnames=fieldnames)
    writer.writeheader()
    
    # Open the input file and loop through each vessel name
    with open(read_path, newline='') as csvfile:
        reader = csv.reader(csvfile)
        driver.get("https://www.bki.co.id/shipregister.html")
        
        for row in reader:
            vessel_name = row[0]
            try:
                search(vessel_name)
                click()
                hull()
                shipdata()
            except:
                try:
                    print('mencoba pergantian iterasi 1')
                    process_ship_name(vessel_name, 1)
                    search(vessel_name)
                    click()
                    hull()
                    shipdata()

                except:
                    try:
                        print('mencoba pergantian iterasi 2')
                        process_ship_name(vessel_name, 2)
                        search(vessel_name)
                        click()
                        hull()
                        shipdata()

                    except:
                        try:
                            print('mencoba pergantian iterasi 3')
                            process_ship_name(vessel_name, 3)
                            search(vessel_name)
                            click()
                            hull()
                            shipdata()

                        except:
                            try:
                                print('mencoba pergantian iterasi 4')
                                process_ship_name(vessel_name, 4)
                                search(vessel_name)
                                click()
                                hull()
                                shipdata()
                            except:
                                print('emang kapalnya gaada di bki')
                details_dict = {'NAME': NAME.text, 'REGISTER': REGISTER.text, 'IMO': IMO.text, 'status': status.text, 'LOA': LOA.text, 'LPP': LPP.text, 'B': B.text, 'H': H.text, 'T': T.text, 'LT': LT.text, 'GT': GT.text, 'NT': NT.text, 'DWT': DWT.text, 'Link': link}
                writer.writerow(details_dict)
